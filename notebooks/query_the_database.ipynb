# %%
import os
import requests
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Database connection setup
db_url = f"postgresql+psycopg2://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/{os.getenv('DB_NAME')}"
engine = create_engine(db_url)

# %%
# Query the full table

query = "SELECT * FROM dune_data;"

dd = pd.read_sql(query, engine)
dd.shape
# Out:
# (483, 10)

# %%
dd
# Out:
#              block_time                                            tx_hash  \
# 0   2024-06-24 20:10:23  0x265338185467fa750d52375be392c56df75f93bea0f1...
# 1   2024-06-17 13:20:35  0xe2472158b2643d02b6c80f6a86c97f293b3268adce0a...
# 2   2024-06-24 01:25:59  0xb255d308279f53ed161791085c30113fff7ff48f8561...
# 3   2024-06-17 02:08:35  0xdf7fd8e04989d59a824a93e1226299addd1d56a9bd13...
# 4   2024-06-19 20:27:23  0xce40c615a3a3425614db1bb2a22c0463dd268b854247...
# ..                  ...                                                ...
# 478 2024-06-29 04:31:11  0xc814b0ac44aab39af0484e2e6356f64bb2b949b439dc...
# 479 2024-06-19 15:05:47  0xb2c772b9ffca86b41a4639458a7c0dd23d31a0f7b57c...
# 480 2024-06-27 14:20:59  0x2f9f1ad63719e289a29b47a94a3bf219148f1ced8bad...
# 481 2024-06-27 14:54:11  0x73c422c7ea886d1f98e8f9c24140d10404365ae3be01...
# 482 2024-06-17 15:22:11  0xbe4c670a2dfe505fa7b33bb28c17723ed6989f705592...
#
# ...

# %%
# Query the full table

query = "SELECT * FROM market_prices;"

mp = pd.read_sql(query, engine)
mp.shape
# Out:
# (718, 11)

# %%
mp
# Out:
#           time     high      low     open  volumefrom      volumeto    close  \
# 0   2024-06-30  3454.57  3348.22  3373.52   113753.11  3.862158e+08  3432.82
# 1   2024-07-26  3286.14  3170.16  3174.48   352369.01  1.143688e+09  3274.89
# 2   2024-07-26  3286.14  3170.16  3174.48   352369.01  1.143688e+09  3274.89
# 3   2024-07-26  3286.14  3170.16  3174.48   352369.01  1.143688e+09  3274.89
# 4   2024-07-27  3328.21  3243.29  3274.89    97951.91  3.209206e+08  3310.73
# ..         ...      ...      ...      ...         ...           ...      ...
# 713 2024-07-27  3328.21  3191.50  3274.89   266332.66  8.703511e+08  3249.36
# 714 2024-07-27  3328.21  3191.50  3274.89   266332.66  8.703511e+08  3249.36
# 715 2024-07-27  3328.21  3191.50  3274.89   266332.66  8.703511e+08  3249.36
# 716 2024-07-27  3328.21  3191.50  3274.89   266332.66  8.703511e+08  3249.36
# 717 2024-07-27  3328.21  3191.50  3274.89   266332.66  8.703511e+08  3249.36
#
# ...

# %%
# Query the full table

query = "SELECT * FROM price_difference;"

pi = pd.read_sql(query, engine)
pi.shape
# Out:
# (483, 5)

# %%
pi
# Out:
#              block_time                                            tx_hash  \
# 0   2024-07-05 09:35:11  0xca98d54ac01704f5161a8c931e726e15d92b9f7ca19b...
# 1   2024-07-23 16:42:11  0x52c967c391598c5090114eba8e247472b798d3b95c58...
# 2   2024-07-16 05:40:59  0xfb2c290e4198446cb38b9a6c7af0554dc64c9f31b982...
# 3   2024-07-08 00:41:59  0x800628fa80b511330f7a1479759bfdddb3ee552a1ee9...
# 4   2024-06-24 20:10:23  0x265338185467fa750d52375be392c56df75f93bea0f1...
# ..                  ...                                                ...
# 478 2024-06-29 04:31:11  0xc814b0ac44aab39af0484e2e6356f64bb2b949b439dc...
# 479 2024-06-19 15:05:47  0xb2c772b9ffca86b41a4639458a7c0dd23d31a0f7b57c...
# 480 2024-06-27 14:20:59  0x2f9f1ad63719e289a29b47a94a3bf219148f1ced8bad...
# 481 2024-06-27 14:54:11  0x73c422c7ea886d1f98e8f9c24140d10404365ae3be01...
# 482 2024-06-17 15:22:11  0xbe4c670a2dfe505fa7b33bb28c17723ed6989f705592...
#
#       sell_price  market_close  difference_percentage
# ...
